# %%
from datetime import datetime
import os

from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %matplotlib inline

#read vaccination data over time per country
vaccination_data=pd.read_csv('owid-covid-data.csv')


#filter out irrelevant columns and lines, and add vaccination percentage column
filtered_vaccination_data=vaccination_data[['iso_code','location','date','people_fully_vaccinated_per_hundred','population']]
filtered_vaccination_data=filtered_vaccination_data.loc[filtered_vaccination_data['date']>'2020-12-15']


#read airport mapping data mappign airport codes to countries. Map countries to 3 digit ISO codes
airport_mapping=pd.read_csv('airport-codes_csv.csv')

def country_mapping(x):
    try:
        y=pycountry.countries.get(alpha_2=x).alpha_3
    except:
        y=''
    return y

airport_mapping['iso_country_3dig']=airport_mapping['iso_country'].apply(country_mapping)

#merge vaccination data and airport mapping
vaccination_airport_mapping=airport_mapping.merge(filtered_vaccination_data, left_on='iso_country_3dig', right_on='iso_code')

#add correctly fotrmatted date column to vaccination data and airport mapping dataset
def datecheck_vac(x):
    return datetime.strptime(x, '%Y-%m-%d').date()

vaccination_airport_mapping['date_num']=vaccination_airport_mapping['date'].apply(datecheck_vac)

#--------------------
#read flight data (sample)
flight_data=pd.read_csv('flight_data/other/flightlist_20210601_20210630.csv')


#change date in flight data from string to datetime object
def datecheck(x):
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S+00:00')

flight_data['firstseen_num']=flight_data['firstseen'].apply(datecheck)
flight_data['lastseen_num']=flight_data['lastseen'].apply(datecheck)
flight_data['date_num']=flight_data['lastseen_num'].apply(datetime.date)

#add columns on airport, country and vaccination rates to flight data, and filter for relevant columns only
flight_data_completed=flight_data.merge(vaccination_airport_mapping, left_on=['origin','date_num'], right_on=['ident','date_num'], how='left')
flight_data_filtered=flight_data_completed[['callsign', 'number', 'icao24', 'registration', 'typecode', 'origin', \
       'destination', 'firstseen_num', 'lastseen_num', 'date_num', 'ident', 'type', 'name', \
        'continent', 'iso_country', 'iso_region', \
       'people_fully_vaccinated_per_hundred', 'population',]]


flight_data_filtered
# Out:
#          callsign number  icao24 registration typecode origin destination  \
# 0         CAO1023    NaN  780c5c       B-2092     B77L   PANC        EHAM
# 1         FDX5021    NaN  ac1e56       N880FD     B77L   KOAK        RJBB
# 2          N750FR    NaN  aa1a96          NaN      NaN   NTAA        1ID3
# 3         AMX9028    NaN  0d09ec       XA-ADD     B789    NaN         NaN
# 4          CCA673    NaN  781161       B-1431     B789   KLAX        LIMC
# ...           ...    ...     ...          ...      ...    ...         ...
# 2540482    N3011K    NaN  a3258e       N3011K      NaN   WA68        KBVS
# 2540483  00000000    NaN  aa67e1        N77NG     B350   KLAX        KPMD
# 2540484    N177GW    NaN  a133d9       N177GW      NaN   K25D        KOEO
# 2540485    N601WT    NaN  a7ccfc       N601WT     AC90   KVNY        CL46
# 2540486    LYM303    NaN  a4a16d       N398KL      SW4   KDEN        CD15
#
#               firstseen_num        lastseen_num    date_num ident  \
# ...
